# %%
from bs4 import BeautifulSoup
from selenium import webdriver

from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

import time
import math

import pandas as pd

s = Service('c:/py_temp/chromedriver.exe')
driver = webdriver.Chrome(service=s)

c = 1
w = 1000064
while w < 1000185 :
    
    if w == 1000090 or w == 1000183 :
        w = w + 1
        URL = ('https://www.jobkorea.co.kr/headhunting/home?part_no=,%s&psTab=40&rOrderTab=1&schstat=1' %w)
        driver.get(URL)
        
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
    
        CNT = int(soup.find('span', 'lhhJobManTot').find('span', 'tahoma').get_text().replace(',', ''))
        PAGE_CNT = math.ceil(CNT/40)
    
        
    else :
        URL = ('https://www.jobkorea.co.kr/headhunting/home?part_no=,%s&psTab=40&rOrderTab=1&schstat=1' %w)
        driver.get(URL)
        
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
    
        CNT = int(soup.find('span', 'lhhJobManTot').find('span', 'tahoma').get_text().replace(',', ''))
        PAGE_CNT = math.ceil(CNT/40)
        
        for a in (1,PAGE_CNT+1) :
            
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            item = soup.find('div','tplList lhhJobList').find_all('tr')
            
            for b in item
            
            #자료번호
            
            print(c)
            NUMB2.append(c)
            
            #고용형태
            
            FORM = b.find('span', 'tplIcnBx').get_text()
            FORM2.append(FORM)
            
            
            #
            
            
            
            
            
            URL2 = ('https://www.jobkorea.co.kr/headhunting/home?jikgub=&careeer=&part_no=,%s&ctype=&scd=&rOrderTab=1&psTab=40&selText=&schstat=1&Page=%s' %(w, a))
            driver.get(URL2)
            
            
PD = pd.DataFrame()
PD['고용형태'] = pd.Series(FORM2)

fc_name = 'C:\\temp\\'+f_dir1+'\\'
PD.to_csv(fc_name, encoding = 'utf-8-sig', index = False)
            
            
            
            
            
            
            
            
    
    w = w + 1

# %%
#----------------------
NUMB2 = []     #자료번호
BTAG2 = []     #　대분류
STAG2 = []     #　소분류
FORM2 = []     #고용형태
CARE2 = []     #요구경력
EDUC2 = []     #요구학력
AREA2 = []     #근무지역
TILT2 = []     #공고제목
NAME2 = []     #기업이름
DATE2 = []     #마감날짜
#----------------------
